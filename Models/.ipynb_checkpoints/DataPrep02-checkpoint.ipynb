# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading the data

# %%
data = pd.read_csv("../DataSets/covid19_who_data.csv")
data.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %% [markdown]
# # EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179883 entries, 0 to 179882
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    179883 non-null  object
#  1   continent                                   169355 non-null  object
#  2   location                                    179883 non-null  object
#  3   date                                        179883 non-null  object
#  4   total_cases                                 173325 non-null  float64
#  5   new_cases                                   173090 non-null  float64
#  6   new_cases_smoothed                          171921 non-null  float64
#  7   total_deaths                                155143 non-null  float64
#  8   new_deaths                                  155129 non-null  float64
# ...

# %%
data.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  1.733250e+05  1.730900e+05        1.719210e+05  1.551430e+05
# mean   2.907924e+06  1.241859e+04        1.245345e+04  6.125176e+04
# std    1.809282e+07  8.861417e+04        8.707442e+04  3.202140e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    2.357000e+03  1.000000e+00        6.857000e+00  8.600000e+01
# 50%    3.068000e+04  7.700000e+01        1.061430e+02  8.410000e+02
# 75%    3.394430e+05  1.071000e+03        1.170714e+03  7.935000e+03
# max    5.050532e+08  4.089061e+06        3.437005e+06  6.199914e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  155129.000000        153982.000000            172523.000000
# mean      165.682316           166.706073             35293.558736
# std       813.052252           796.262060             65022.787344
# min         0.000000             0.000000                 0.001000
# ...

# %% [markdown]
# # Data Cleaning

# %%
 a = data.isnull().sum()
print(a)
# Out:
# iso_code                                        0
# continent                                   10528
# location                                        0
# date                                            0
# total_cases                                  6558
#                                             ...
# human_development_index                     35138
# excess_mortality_cumulative_absolute       173805
# excess_mortality_cumulative                173805
# excess_mortality                           173805
# excess_mortality_cumulative_per_million    173805
# Length: 67, dtype: int64

# %%
data.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
usefull_columns_stats = ['date', 'continent', 'location', 'total_cases', 'total_deaths', 'total_cases_per_million', 'total_deaths_per_million', 'total_vaccinations_per_hundred', 'population', 'population_density', 'diabetes_prevalence', 'female_smokers', 'male_smokers', 'gdp_per_capita', 'extreme_poverty', 'hospital_beds_per_thousand', 'life_expectancy', 'human_development_index']

# %%
data = data[usefull_columns_stats]

# %%
data.isnull().sum()
# Out:
# date                                   0
# continent                          10528
# location                               0
# total_cases                         6558
# total_deaths                       24740
# total_cases_per_million             7360
# total_deaths_per_million           25529
# total_vaccinations_per_hundred    131095
# population                          1119
# population_density                 19628
# diabetes_prevalence                24465
# female_smokers                     67331
# male_smokers                       68874
# gdp_per_capita                     31749
# extreme_poverty                    83008
# hospital_beds_per_thousand         48480
# life_expectancy                    11695
# human_development_index            35138
# dtype: int64

# %%
data.dropna(inplace=True)
data.sort_values(by='date', ascending=False, inplace=True)
data
# Out:
#               date continent  location  total_cases  total_deaths  \
# 179882  2022-04-18    Africa  Zimbabwe     247297.0        5464.0
# 25657   2022-04-18    Europe  Bulgaria    1150342.0       36810.0
# 124882  2022-04-18      Asia  Pakistan    1527411.0       30364.0
# 122498  2022-04-18    Europe    Norway    1420033.0        2783.0
# 34237   2022-04-18      Asia     China     630678.0        4648.0
# ...            ...       ...       ...          ...           ...
# 43320   2020-12-08    Europe   Denmark      94799.0         901.0
# 122002  2020-12-08    Europe    Norway      39163.0         361.0
# 89730   2020-12-07    Europe    Latvia      21520.0         272.0
# 89727   2020-12-04    Europe    Latvia      19993.0         242.0
# 121996  2020-12-02    Europe    Norway      36969.0         351.0
#
#         total_cases_per_million  total_deaths_per_million  \
# 179882                16385.780                   362.042
# ...

# %%
data = data[data['date'] == '2022-04-18']

# %%
len(pd.unique(data['location']))
# Out:
# 39

# %%
data.to_csv('../DataSets/StatData.csv')

# %%
pd.unique(data['location'])
# Out:
# array(['Zimbabwe', 'Bulgaria', 'Pakistan', 'Norway', 'China', 'Croatia',
#        'Djibouti', 'El Salvador', 'Nepal', 'Estonia', 'Fiji', 'Greece',
#        'Turkey', 'Hungary', 'India', 'Indonesia', 'Iran', 'South Africa',
#        'Morocco', 'Montenegro', 'Israel', 'Thailand', 'Mongolia', 'Italy',
#        'Kyrgyzstan', 'Laos', 'Latvia', 'Lithuania', 'Malaysia',
#        'South Korea', 'Malta', 'Russia', 'Georgia', 'Australia',
#        'Uruguay', 'Romania', 'Brazil', 'Bangladesh', 'Zambia'],
#       dtype=object)
