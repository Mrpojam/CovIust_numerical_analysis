# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('statistical_data.csv')
data.head()
# Out:
#    Unnamed: 0   population  population_density  total_cases  total_deaths  \
# 0       10249   25788217.0               3.202    5459012.0        6804.0
# 1       61797   83900471.0             237.016   23459628.0      132960.0
# 2       57905   67422000.0             122.578   27844621.0      144274.0
# 3      152851   46745211.0              93.105   11627487.0      103104.0
# 4       47689  104258327.0              97.999     511977.0       24522.0
#
#    gdp_per_capita  human_development_index  diabetes_prevalence  \
# 0       44648.710                    0.944                 5.07
# 1       45229.245                    0.947                 8.31
# 2       38605.671                    0.901                 4.77
# 3       34272.360                    0.904                 7.17
# 4       10550.206                    0.707                17.31
#
#    female_smokers  male_smokers  hospital_beds_per_thousand     country
# ...

# %%
data.describe()
# Out:
#           Unnamed: 0    population  population_density   total_cases  \
# count       6.000000  6.000000e+00            6.000000  6.000000e+00
# mean    68051.500000  6.885716e+07          100.621833  1.268528e+07
# std     47295.180235  2.859020e+07           79.017918  1.074625e+07
# min     10249.000000  2.578822e+07            3.202000  5.119770e+05
# 25%     50243.000000  5.191441e+07           60.649500  5.896501e+06
# 50%     59851.000000  7.566124e+07           95.552000  9.418228e+06
# 75%     73812.750000  8.474669e+07          116.433250  2.050159e+07
# max    152851.000000  1.042583e+08          237.016000  2.784462e+07
#
#         total_deaths  gdp_per_capita  human_development_index  \
# count       6.000000        6.000000                 6.000000
# mean    92086.333333    32064.802000                 0.864333
# std     61207.677602    14217.794978                 0.097434
# min      6804.000000    10550.206000                 0.707000
# ...

# %%
data['smokers'] = data['female_smokers'] + data['male_smokers']

# %%
sns.barplot(data=data, x='country', y='gdp_per_capita')
# Out:
# <AxesSubplot:xlabel='country', ylabel='gdp_per_capita'>

# %%
sns.barplot(data=data, x='country', y='population')
# Out:
# <AxesSubplot:xlabel='country', ylabel='population'>

# %%
sns.barplot(data=data, x='country', y='smokers')
# Out:
# <AxesSubplot:xlabel='country', ylabel='smokers'>

# %%
sns.barplot(data=data, x='country', y='male_smokers')
# Out:
# <AxesSubplot:xlabel='country', ylabel='male_smokers'>

# %%
sns.barplot(data=data, x='country', y='female_smokers')
# Out:
# <AxesSubplot:xlabel='country', ylabel='female_smokers'>

# %%
sns.barplot(data=data, x='country', y='total_cases')
# Out:
# <AxesSubplot:xlabel='country', ylabel='total_cases'>

# %%
sns.barplot(data=data, x='country', y='total_deaths')
# Out:
# <AxesSubplot:xlabel='country', ylabel='total_deaths'>

# %%
sns.relplot(x=data['total_cases'], y=data['total_deaths'], hue=data['country'],size=data['population_density'])

# %%
sns.relplot(x=data['total_cases'], y=data['total_deaths'], hue=data['country'],size=data['population'])

# %%
sns.relplot(x=data['population'], y=data['total_deaths'], hue=data['country'],size=data['population_density'])

# %%
sns.regplot(x=data['total_cases'], y=data['total_deaths'])
# Out:
# <AxesSubplot:xlabel='total_cases', ylabel='total_deaths'>

# %%
sns.regplot(x=data['population_density'], y=data['total_deaths'])
# Out:
# <AxesSubplot:xlabel='population_density', ylabel='total_deaths'>

# %%
sns.relplot(data=data, x='total_cases', y='total_deaths', hue='country', size='gdp_per_capita')

# %%
sns.relplot(data=data, x='total_cases', y='total_deaths', hue='country', size='human_development_index')

# %%
sns.relplot(data=data, x='total_cases', y='total_deaths', hue='country', size='hospital_beds_per_thousand')
