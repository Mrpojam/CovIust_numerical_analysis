# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading Data

# %%
data = pd.read_csv('../DataSets/StatData.csv')
data.head()
# Out:
#    Unnamed: 0        date continent  location  total_cases  total_deaths  \
# 0      179882  2022-04-18    Africa  Zimbabwe     247297.0        5464.0
# 1       25657  2022-04-18    Europe  Bulgaria    1150342.0       36810.0
# 2      124882  2022-04-18      Asia  Pakistan    1527411.0       30364.0
# 3      122498  2022-04-18    Europe    Norway    1420033.0        2783.0
# 4       34237  2022-04-18      Asia     China     630678.0        4648.0
#
#    total_cases_per_million  total_deaths_per_million  \
# 0                16385.780                   362.042
# 1               166797.092                  5337.370
# 2                 6782.467                   134.831
# 3               259811.451                   509.182
# 4                  436.692                     3.218
#
#    total_vaccinations_per_hundred    population  population_density  \
# 0                           67.27  1.509217e+07              42.729
# ...

# %%
data= data.drop('Unnamed: 0', axis = 1)
data = data.drop('date', axis = 1)
data
# Out:
#         continent      location  total_cases  total_deaths  \
# 0          Africa      Zimbabwe     247297.0        5464.0
# 1          Europe      Bulgaria    1150342.0       36810.0
# 2            Asia      Pakistan    1527411.0       30364.0
# 3          Europe        Norway    1420033.0        2783.0
# 4            Asia         China     630678.0        4648.0
# 5          Europe       Croatia    1113547.0       15742.0
# 6          Africa      Djibouti      15598.0         189.0
# 7   North America   El Salvador     162089.0        4125.0
# 8            Asia         Nepal     978674.0       11951.0
# 9          Europe       Estonia     567644.0        2522.0
# 10        Oceania          Fiji      64513.0         862.0
# 11         Europe        Greece    3242037.0       28652.0
# 12           Asia        Turkey   14999479.0       98587.0
# 13         Europe       Hungary    1879480.0       45865.0
# 14           Asia         India   43045527.0      521966.0
# ...

# %% [markdown]
# # EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      39 non-null     int64
#  1   date                            39 non-null     object
#  2   continent                       39 non-null     object
#  3   location                        39 non-null     object
#  4   total_cases                     39 non-null     float64
#  5   total_deaths                    39 non-null     float64
#  6   total_cases_per_million         39 non-null     float64
#  7   total_deaths_per_million        39 non-null     float64
#  8   total_vaccinations_per_hundred  39 non-null     float64
#  9   population                      39 non-null     float64
#  10  population_density              39 non-null     float64
#  11  diabetes_prevalence             39 non-null     float64
# ...

# %%
data.describe()
# Out:
#         total_cases   total_deaths  total_cases_per_million  \
# count  3.900000e+01      39.000000                39.000000
# mean   5.093601e+06   68246.102564            165431.443051
# std    8.951810e+06  142138.809101            143745.947277
# min    1.559800e+04     189.000000               436.692000
# 25%    5.991610e+05    4049.000000             30606.763000
# 50%    1.420033e+06   15742.000000            141411.287000
# 75%    4.230004e+06   41337.500000            266699.691500
# max    4.304553e+07  662271.000000            435603.508000
#
#        total_deaths_per_million  total_vaccinations_per_hundred    population  \
# count                 39.000000                       39.000000  3.900000e+01
# mean                1604.380308                      148.883590  1.164577e+08
# std                 1518.854106                       61.249822  3.143509e+08
# min                    3.218000                       17.430000  5.161000e+05
# ...

# %% [markdown]
# # Stat analysis

# %%
sns.set(rc={'figure.figsize':(15,15)})

# %%
sns.regplot(x=data['total_cases_per_million'], y=data['total_deaths_per_million'])
plt.savefig('../Plots/case_death.png')

# %%
sns.scatterplot(x=data['total_cases_per_million'], y=data['total_deaths_per_million'], size=data['gdp_per_capita'])
plt.savefig('../Plots/case_death_gdp.png')

# %%
sns.set(rc={'figure.figsize':(15.7,15.27)})

# %%
sns.scatterplot(x=data['population_density'], y=data['hospital_beds_per_thousand'], hue=data['location'], size=data['extreme_poverty'])
plt.savefig('../Plots/case_hospital_povery.png')

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'date', 'continent', 'location', 'total_cases',
#        'total_deaths', 'total_cases_per_million', 'total_deaths_per_million',
#        'total_vaccinations_per_hundred', 'population', 'population_density',
#        'diabetes_prevalence', 'female_smokers', 'male_smokers',
#        'gdp_per_capita', 'extreme_poverty', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index'],
#       dtype='object')

# %%
sns.regplot(x=data['gdp_per_capita'], y=data['extreme_poverty'])
plt.savefig('../Plots/gdp_pov_reg.png')

# %%
sns.regplot(x=data['human_development_index'], y=data['total_deaths_per_million'])
plt.savefig('../Plots/dev_death.png')

# %%
sns.regplot(x=data['life_expectancy'], y=data['total_deaths_per_million'])
plt.savefig('../Plots/life_death.png')

# %%
sns.scatterplot(x=data['life_expectancy'], y = data['total_deaths_per_million'], size=data['gdp_per_capita'])
# Out:
# <AxesSubplot:xlabel='life_expectancy', ylabel='total_deaths_per_million'>

# %%
sns.heatmap(data.corr());
plt.savefig('../Plots/cor.png')

# %%
sns.set(rc={'figure.figsize':(15,15)})
sns.relplot(x=data['total_cases_per_million'], y=data['total_deaths_per_million'], size=data['total_vaccinations_per_hundred'])

# %%
sns.regplot(x=data['total_vaccinations_per_hundred'], y=data['total_deaths_per_million'])
# Out:
# <AxesSubplot:xlabel='total_vaccinations_per_hundred', ylabel='total_deaths_per_million'>

# %%
sns.histplot(x=data['total_vaccinations_per_hundred'], kde='kind')
# Out:
# <AxesSubplot:xlabel='total_vaccinations_per_hundred', ylabel='Count'>

# %%
sns.histplot(x=data['male_smokers'], kde='kind')
plt.savefig('../Plots/male_smokers_hist.png')

# %%
sns.histplot(x=data['female_smokers'])
# Out:
# <AxesSubplot:xlabel='female_smokers', ylabel='Count'>

# %%
sns.regplot(x=data['male_smokers'], y=data['total_deaths_per_million'])
plt.savefig('../Plots/male_smokers.png')

# %%
sns.regplot(x=data['total_deaths_per_million'], y=data['hospital_beds_per_thousand'])
# Out:
# <AxesSubplot:xlabel='total_deaths_per_million', ylabel='hospital_beds_per_thousand'>

# %%
sns.regplot(x=data['female_smokers'], y=data['total_deaths_per_million'])
plt.savefig('../Plots/fsmokers_box.png')

# %%
sns.boxplot(data=data[['total_deaths_per_million']])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=data[['total_cases_per_million']])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=data[['male_smokers', 'female_smokers']])
plt.savefig('../Plots/smokers_box.png')

# %%
new_data = data[data['location'] != 'China']
new_data = new_data[new_data['location'] != 'India']

# %%
sns.boxplot(data=new_data['population'])
# Out:
# <AxesSubplot:>

# %%
data.sort_values(by='population', ascending=False)
# Out:
#     Unnamed: 0        date      continent      location  total_cases  \
# 4        34237  2022-04-18           Asia         China     630678.0
# 14       75448  2022-04-18           Asia         India   43045527.0
# 15       76226  2022-04-18           Asia     Indonesia    6040432.0
# 2       124882  2022-04-18           Asia      Pakistan    1527411.0
# 36       23362  2022-04-18  South America        Brazil   30261088.0
# 37       14133  2022-04-18           Asia    Bangladesh    1952362.0
# 31      134571  2022-04-18         Europe        Russia   17820486.0
# 12      165012  2022-04-18           Asia        Turkey   14999479.0
# 16       77818  2022-04-18           Asia          Iran    7208968.0
# 21      160689  2022-04-18           Asia      Thailand    4063844.0
# 23       81741  2022-04-18         Europe         Italy   15730676.0
# 17      149694  2022-04-18         Africa  South Africa    3742107.0
# 29      151299  2022-04-18           Asia   South Korea   16471940.0
# ...

# %%
sns.set(rc={'figure.figsize':(15.7,15.27)})
data = data.sort_values(by='population')
sns.barplot(x=data['location'], y=data['population'])
# Out:
# <AxesSubplot:xlabel='location', ylabel='population'>

# %%
data = data.sort_values(by='population')
sns.barplot(x=data['location'], y=data['total_cases_per_million'])
# Out:
# <AxesSubplot:xlabel='location', ylabel='total_cases_per_million'>

# %%
data = data.sort_values(by='population')
sns.barplot(x=data['location'], y=data['total_vaccinations_per_hundred'])
# Out:
# <AxesSubplot:xlabel='location', ylabel='total_vaccinations_per_hundred'>

# %%
sns.kdeplot(x=data['total_cases_per_million'], y=data['total_deaths_per_million'])
# Out:
# <AxesSubplot:xlabel='total_cases_per_million', ylabel='total_deaths_per_million'>

# %%
sns.kdeplot(x=data['gdp_per_capita'], y=data['hospital_beds_per_thousand'])
# Out:
# <AxesSubplot:xlabel='gdp_per_capita', ylabel='hospital_beds_per_thousand'>

# %%
sns.jointplot(x=data['total_cases_per_million'], y=data['total_deaths_per_million'])
